# %%
import os
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
os.chdir("/Users/jabras/Downloads/")

# %%
df = pd.read_csv("MBA 506 (602) SUM1 2020-Final Exam-grades.csv", sep = ",")

# %%
df.head()
# Out:
#    Last name First name      Email address     State              Started on  \
# 0      Zarin        Sam  sjharri3@ncsu.edu  Finished   June 14 2020  6:37 AM
# 1     Lawlor      Bryce   blawlor@ncsu.edu  Finished   June 14 2020  8:57 AM
# 2  Pelletier  Mary Beth  mepelle2@ncsu.edu  Finished   June 14 2020  9:32 AM
# 3    Slappey    Kristen  knslappe@ncsu.edu  Finished  June 14 2020  10:41 AM
# 4      Lodha     Sumeet   slodha2@ncsu.edu  Finished  June 14 2020  12:15 PM
#
#                 Completed       Time taken    Grade/100.00  Q. 1 /4.40  \
# 0   June 14 2020  9:43 AM   3 hours 5 mins  Not yet graded         4.4
# 1  June 14 2020  11:26 AM  2 hours 28 mins  Not yet graded         4.4
# 2   June 14 2020  1:00 PM  3 hours 27 mins  Not yet graded         4.4
# 3   June 14 2020  1:35 PM  2 hours 53 mins  Not yet graded         4.4
# 4   June 14 2020  4:08 PM  3 hours 52 mins  Not yet graded         4.4
#
#   Q. 2 /4.40  ...  Q. 24 /1.10 Q. 25 /1.10 Q. 26 /1.10 Q. 27 /1.10  \
# ...

# %%
df = df.replace('-', 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 41 columns):
# Last name        55 non-null object
# First name       54 non-null object
# Email address    54 non-null object
# State            54 non-null object
# Started on       54 non-null object
# Completed        54 non-null object
# Time taken       54 non-null object
# Grade/100.00     55 non-null object
# Q. 1 /4.40       55 non-null float64
# Q. 2 /4.40       55 non-null object
# Q. 3 /7.69       55 non-null float64
# Q. 4 /8.79       55 non-null object
# Q. 5 /8.79       55 non-null object
# Q. 6 /5.49       55 non-null object
# Q. 7 /5.49       55 non-null object
# Q. 8 /5.49       55 non-null float64
# Q. 9 /5.49       55 non-null object
# Q. 10 /5.49      55 non-null object
# Q. 11 /9.89      55 non-null object
# Q. 12 /1.10      55 non-null float64
# Q. 13 /1.10      55 non-null float64
# Q. 14 /1.10      55 non-null float64
# Q. 15 /1.10      55 non-null float64
# ...

# %%
df.describe()
# Out:
#        Q. 1 /4.40  Q. 3 /7.69  Q. 8 /5.49  Q. 12 /1.10  Q. 13 /1.10  \
# count   55.000000   55.000000   55.000000    55.000000    55.000000
# mean     3.992545    2.990545    2.541636     1.079636     1.018545
# std      1.275387    3.748860    2.737459     0.148299     0.288081
# min      0.000000    0.000000    0.000000     0.000000     0.000000
# 25%      4.400000    0.000000    0.000000     1.100000     1.100000
# 50%      4.400000    0.000000    0.000000     1.100000     1.100000
# 75%      4.400000    7.690000    5.490000     1.100000     1.100000
# max      4.400000    7.690000    5.490000     1.100000     1.100000
#
#        Q. 14 /1.10  Q. 15 /1.10  Q. 16 /1.10  Q. 17 /1.10  Q. 18 /1.10  ...  \
# count    55.000000    55.000000         55.0    55.000000    55.000000  ...
# mean      0.896364     0.896364          1.1     1.079636     0.814727  ...
# std       0.427293     0.427293          0.0     0.148299     0.377815  ...
# ...

# %%
# separate question 12 on 
df_q = df.iloc[:, 19:]

# %%
df_q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 22 columns):
# Q. 12 /1.10    55 non-null float64
# Q. 13 /1.10    55 non-null float64
# Q. 14 /1.10    55 non-null float64
# Q. 15 /1.10    55 non-null float64
# Q. 16 /1.10    55 non-null float64
# Q. 17 /1.10    55 non-null float64
# Q. 18 /1.10    55 non-null float64
# Q. 19 /1.10    55 non-null float64
# Q. 20 /1.10    55 non-null float64
# Q. 21 /1.10    55 non-null float64
# Q. 22 /1.10    55 non-null float64
# Q. 23 /1.10    55 non-null float64
# Q. 24 /1.10    55 non-null float64
# Q. 25 /1.10    55 non-null float64
# Q. 26 /1.10    55 non-null float64
# Q. 27 /1.10    55 non-null float64
# Q. 28 /1.10    55 non-null float64
# Q. 29 /1.10    55 non-null float64
# Q. 30 /2.20    55 non-null float64
# Q. 31 /2.20    55 non-null float64
# Q. 32 /2.20    55 non-null float64
# Q. 33 /2.20    55 non-null float64
# dtypes: float64(22)
# memory usage: 9.6 KB

# %%
# list averages of questions - look more into Q 29, Q33, Q32, Q21, Q24, Q15, Q14, 
df_q.describe()
# Out:
#        Q. 12 /1.10  Q. 13 /1.10  Q. 14 /1.10  Q. 15 /1.10  Q. 16 /1.10  \
# count    55.000000    55.000000    55.000000    55.000000         55.0
# mean      1.079636     1.018545     0.896364     0.896364          1.1
# std       0.148299     0.288081     0.427293     0.427293          0.0
# min       0.000000     0.000000     0.000000     0.000000          1.1
# 25%       1.100000     1.100000     1.100000     1.100000          1.1
# 50%       1.100000     1.100000     1.100000     1.100000          1.1
# 75%       1.100000     1.100000     1.100000     1.100000          1.1
# max       1.100000     1.100000     1.100000     1.100000          1.1
#
#        Q. 17 /1.10  Q. 18 /1.10  Q. 19 /1.10  Q. 20 /1.10  Q. 21 /1.10  ...  \
# count    55.000000    55.000000    55.000000         55.0    55.000000  ...
# mean      1.079636     0.814727     1.038909          1.1     0.937091  ...
# std       0.148299     0.377815     0.251968          0.0     0.390772  ...
# ...

# %%
df_q["Q. 29 /1.10"].value_counts().plot(kind='barh') # need to check this one out

# %%
df_q["Q. 33 /2.20"].value_counts().plot(kind='barh') # maybe?

# %%
df_q["Q. 15 /1.10"].value_counts().plot(kind='barh') # maybe

# %%
df_q["Q. 14 /1.10"].value_counts().plot(kind='barh') # maybe
