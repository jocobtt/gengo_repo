# %%
import pandas as pd 
import os 
import numpy as np 
import seaborn as sns
import pycurl 
from helium import *

# %%
df = pd.read_csv("MBA 506 (602) SUM1 2020-Week 2 Quiz-grades.csv", sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 18 columns):
# Last name        99 non-null object
# First name       98 non-null object
# Email address    98 non-null object
# State            98 non-null object
# Started on       98 non-null object
# Completed        98 non-null object
# Time taken       98 non-null object
# Grade/10         99 non-null int64
# Q. 1 /1          99 non-null object
# Q. 2 /1          99 non-null object
# Q. 3 /1          99 non-null object
# Q. 4 /1          99 non-null object
# Q. 5 /1          99 non-null object
# Q. 6 /1          99 non-null object
# Q. 7 /1          99 non-null object
# Q. 8 /1          99 non-null object
# Q. 9 /1          99 non-null object
# Q. 10 /1         99 non-null object
# dtypes: int64(1), object(17)
# memory usage: 14.0+ KB

# %%
# loop through to find "-" marks & turn into int
df = df.replace('-', 0)
#df = df['Q. 1 /1'].apply(lambda s: eval(str(s)))

# %%
# this will log me into moodle 
start_chrome('')
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="beeeea36f67c8a32cb2434a73b920cb0")>

# %%
def turn2int(quiz_num):
    # begin pulling using helium 
    # working on this part still
    # set url value 
    
    # change directory to where file is downloaded
    os.chdir("~/Downloads")
    
    # read in dataset 
    df = pd.read_csv('')
    
    # remove "-" values and turn them into 0's
    data = dataset.replace('-', 0)
    
    # splice dataset to only take 7th on value 
    df_questions = df.iloc[:, 7:]
    
    
    for x in df_questions:
        df_qustions = df_questions.astype(int)
        
    # print out mean, stdev etc. from dataset

# %%
df_q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 11 columns):
# Grade/10    99 non-null int64
# Q. 1 /1     99 non-null object
# Q. 2 /1     99 non-null object
# Q. 3 /1     99 non-null object
# Q. 4 /1     99 non-null object
# Q. 5 /1     99 non-null object
# Q. 6 /1     99 non-null object
# Q. 7 /1     99 non-null object
# Q. 8 /1     99 non-null object
# Q. 9 /1     99 non-null object
# Q. 10 /1    99 non-null object
# dtypes: int64(1), object(10)
# memory usage: 8.6+ KB

# %%
for x in df_q:
    print(x)
# Out:
# Grade/10
# Q. 1 /1
# Q. 2 /1
# Q. 3 /1
# Q. 4 /1
# Q. 5 /1
# Q. 6 /1
# Q. 7 /1
# Q. 8 /1
# Q. 9 /1
# Q. 10 /1

# %%
for x in question:
    print(x.mean())

# %%
# calculate average time taken
df['Time taken'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     550     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 551     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     552
#
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#
# TypeError: can only concatenate str (not "int") to str
#
# ...

# %%
# load in dataset for Quiz 3
os.chdir("../../../../../Downloads")

# %%
df_2 = pd.read_csv('MBA 506 (602) SUM1 2020-week 3 quiz-grades.csv', sep = ',')

# %%
df_2.head()
# Out:
#    Last name First name      Email address     State             Started on  \
# 0  Pelletier  Mary Beth  mepelle2@ncsu.edu  Finished   May 24 2020  4:18 PM
# 1       Duan       Zane     zduan@ncsu.edu  Finished   May 27 2020  4:05 PM
# 2       Duan       Zane     zduan@ncsu.edu  Finished   May 27 2020  4:20 PM
# 3    Slappey    Kristen  knslappe@ncsu.edu  Finished   May 27 2020  9:39 PM
# 4      Zarin        Sam  sjharri3@ncsu.edu  Finished  May 28 2020  10:26 AM
#
#                Completed       Time taken  Grade/10  Q. 1 /1  Q. 2 /1  \
# 0   May 24 2020  4:38 PM  20 mins 11 secs         9        1        1
# 1   May 27 2020  4:19 PM  13 mins 59 secs         8        1        1
# 2   May 27 2020  4:29 PM   9 mins 49 secs         8        1        1
# 3   May 27 2020  9:56 PM  16 mins 27 secs        10        1        1
# 4  May 28 2020  10:36 AM   9 mins 54 secs         6        1        1
#
#    Q. 3 /1  Q. 4 /1 Q. 5 /1  Q. 6 /1  Q. 7 /1  Q. 8 /1  Q. 9 /1 Q. 10 /1  \
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 19 columns):
# Last name        94 non-null object
# First name       93 non-null object
# Email address    93 non-null object
# State            93 non-null object
# Started on       93 non-null object
# Completed        93 non-null object
# Time taken       93 non-null object
# Grade/10         94 non-null int64
# Q. 1 /1          94 non-null int64
# Q. 2 /1          94 non-null int64
# Q. 3 /1          94 non-null int64
# Q. 4 /1          94 non-null int64
# Q. 5 /1          94 non-null object
# Q. 6 /1          94 non-null int64
# Q. 7 /1          94 non-null int64
# Q. 8 /1          94 non-null int64
# Q. 9 /1          94 non-null int64
# Q. 10 /1         94 non-null int64
# Q. 11 /1         94 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 14.1+ KB

# %%
df_2.describe()
# Out:
#        Grade/10    Q. 1 /1    Q. 2 /1    Q. 3 /1    Q. 4 /1    Q. 5 /1  \
# count  94.00000  94.000000  94.000000  94.000000  94.000000  94.000000
# mean    8.37234   0.882979   0.882979   0.617021   0.851064   0.819149
# std     1.29502   0.323169   0.323169   0.488720   0.357935   0.386959
# min     5.00000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     8.00000   1.000000   1.000000   0.000000   1.000000   1.000000
# 50%     8.00000   1.000000   1.000000   1.000000   1.000000   1.000000
# 75%     9.00000   1.000000   1.000000   1.000000   1.000000   1.000000
# max    10.00000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#          Q. 6 /1    Q. 7 /1   Q. 8 /1   Q. 9 /1   Q. 10 /1   Q. 11 /1
# count  94.000000  94.000000  94.00000  94.00000  94.000000  94.000000
# mean    0.968085   0.617021   0.93617   0.93617   0.904255   0.904255
# std     0.176716   0.488720   0.24576   0.24576   0.295818   0.295818
# ...

# %%
df_2 = df_2.drop(columns= ["Q. 11/1"], axis=0)

# %%
df_2 = df_2.replace('-', 0)

# %%
# convert necessary rows into int - 11, 10, 9 & 5
#df_2['Q. 5 /1'] = df_2['Q. 5 /1'].astype(int)

# %%
df_2["Grade/10"].groupby(df_2['Email address']).min()
# Out:
# Email address
# aamanriq@ncsu.edu     6
# achurle2@ncsu.edu     8
# admelton@ncsu.edu     7
# ageorge5@ncsu.edu     8
# amhunte4@ncsu.edu    10
# arshah2@ncsu.edu      9
# bajorda2@ncsu.edu     8
# bfhayes@ncsu.edu      7
# bjruhaak@ncsu.edu     8
# blnona@ncsu.edu       8
# bmlittle@ncsu.edu     8
# brlandav@ncsu.edu     6
# carice6@ncsu.edu      8
# ccdonahu@ncsu.edu     8
# cfelts@ncsu.edu      10
# cifill@ncsu.edu      10
# clcabani@ncsu.edu     6
# cmayorg@ncsu.edu      8
# cmcdona4@ncsu.edu     7
# dbreile@ncsu.edu      9
# dcbinda@ncsu.edu     10
# djatwood@ncsu.edu    10
# dlwill23@ncsu.edu     9
# gldavis2@ncsu.edu     6
# hbstix@ncsu.edu       7
# jabronch@ncsu.edu     6
# jcmurrel@ncsu.edu     7
# jgbadget@ncsu.edu    10
# jmdrummo@ncsu.edu     8
# jmedlin@ncsu.edu      5
# knslappe@ncsu.edu    10
# ksarawa@ncsu.edu     10
# ktkatz@ncsu.edu       8
# lachnin@ncsu.edu      7
# lagrier2@ncsu.edu     9
# lalennon@ncsu.edu     6
# mepelle2@ncsu.edu     9
# ...
